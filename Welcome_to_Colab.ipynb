# %% [markdown]
# <a href="https://colab.research.google.com/github/fenz09/repo-for-cv/blob/repo/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1 = [10, 20, 25, 30, 35]
list2 = [40, 45, 60, 75, 90]
results_list = []

for i in range(len(list1)):
  if(list1[i] %2!=0):
    results_list.append(list1[i])

for i in range(len(list2)):
  if(list2[i] %2!=0):
    results_list.append(list2[i])

print (results_list)
# Out:
# [25, 35, 45, 75]
